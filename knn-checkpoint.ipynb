# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Column names
columns = ["sepal-width","sepal-length","petal-width","petal-length","iris-type"]

# ✅ FIX 1: Correct file reading
df = pd.read_csv("iris_dataset.csv", sep="\t", names=columns)

# Setting X & Y
X = df.iloc[:, [0,1,2,3]].values
Y = df.iloc[:, -1].values   # 1D is better

# Train-test split
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=1/5
)

# Standardization
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)   # ✅ FIX 2

# %%
# Initialize KNN with 5 neighbors
knclassifier = KNeighborsClassifier(n_neighbors =5)
knclassifier.fit(X_train,Y_train.ravel())

# Predict & Check accuracy Score
Y_Predict = knclassifier.predict(X_test)
print("Accuracy",metrics.accuracy_score(Y_test,Y_Predict))
# Out:
# Accuracy 1.0
