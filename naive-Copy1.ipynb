# %%
from functools import reduce
import pandas as pd
import pprint


class Classifier:
    def __init__(self, filename=None, class_attr=None):
        """
        probability(class) =    How many times it appears in column
                             __________________________________________
                                  count of all class attribute
        """
        self.data = pd.read_csv(filename, sep=',', header=0)
        self.class_attr = class_attr
        self.priori = {}
        self.cp = {}
        self.hypothesis = None

    def calculate_priori(self):
        class_values = list(set(self.data[self.class_attr]))
        class_data = list(self.data[self.class_attr])

        for i in class_values:
            self.priori[i] = class_data.count(i) / float(len(class_data))

        print("Priori Values:", self.priori)

    def get_cp(self, attr, attr_type, class_value):
        data_attr = list(self.data[attr])
        class_data = list(self.data[self.class_attr])
        total = 1

        for i in range(len(data_attr)):
            if class_data[i] == class_value and data_attr[i] == attr_type:
                total += 1

        return total / float(class_data.count(class_value))

    def calculate_conditional_probabilities(self, hypothesis):
        for class_value in self.priori:
            self.cp[class_value] = self.priori[class_value]
            for attr, attr_type in hypothesis.items():
                self.cp[class_value] *= self.get_cp(attr, attr_type, class_value)

        print("Conditional Probabilities:", self.cp)

    def classify(self):
        result = max(self.cp, key=self.cp.get)
        print("Predicted Class:", result)

# %%
c = Classifier(filename="weather.csv", class_attr="Play")

c.calculate_priori()

c.hypothesis = {
    "Outlook": "Rainy",
    "Temp": "Mild",
    "Humidity": "Normal",
    "Windy": "t"
}

c.calculate_conditional_probabilities(c.hypothesis)
c.classify()
# Out:
# Priori Values: {'no': 0.35714285714285715, 'yes': 0.6428571428571429}
# Conditional Probabilities: {'no': 0.054857142857142875, 'yes': 0.0411522633744856}
# Predicted Class: no
